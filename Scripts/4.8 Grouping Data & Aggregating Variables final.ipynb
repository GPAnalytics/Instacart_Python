# %% [markdown]
# # Importing data and libraries

# %%
# import libraries
import pandas as pd
import numpy as np
import os

# %%
path = r'C:\Users\Goce\Desktop\Achievement 4 Python Fundamentals' #Defining path

# %%
ords_prods_merge = pd.read_pickle(os.path.join(path, 'Data', 'Prepared Data', 'orders_products_merged_updated.pkl'),)  # Importing orders_products_merged_updated

# %% [markdown]
# # Dealing with memory issues

# %%
#checking the dataframe
ords_prods_merge.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2398795        1             2                   3                  7
# 2    473747        1             3                   3                 12
# 3   2254736        1             4                   4                  7
# 4    431534        1             5                   4                 15
#
#    days_since_last-order  new_customer  product_id  add_to_cart_order  \
# 0                    NaN          True         196                  1
# 1                   15.0         False         196                  1
# 2                   21.0         False         196                  1
# 3                   29.0         False         196                  1
# 4                   28.0         False         196                  1
#
#    reordered  ... Unnamed: 0  product_name aisle_id  department_id  prices  \
# ...

# %%
#checking the dataframe
ords_prods_merge.tail()
# Out:
#           order_id  user_id  order_number  orders_day_of_week  \
# 32404854   1320836   202557            17                   2
# 32404855     31526   202557            18                   5
# 32404856    758936   203436             1                   2
# 32404857   2745165   203436             2                   3
# 32404858   3093936   205420             1                   4
#
#           order_hour_of_day  days_since_last-order  new_customer  product_id  \
# 32404854                 15                    1.0         False       43553
# 32404855                 11                    3.0         False       43553
# 32404856                  7                    NaN          True       42338
# 32404857                  5                   15.0         False       42338
# 32404858                 14                    NaN          True       28818
#
#           add_to_cart_order  reordered  ... Unnamed: 0  \
# 32404854                  2          1  ...      43557
# ...

# %%
pd.set_option('display.max_columns', None)  # Show all columns

# %%
ords_prods_merge.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 32404859 entries, 0 to 32404858
# Data columns (total 21 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   order_id               int64
#  1   user_id                int64
#  2   order_number           int64
#  3   orders_day_of_week     int64
#  4   order_hour_of_day      int64
#  5   days_since_last-order  float64
#  6   new_customer           bool
#  7   product_id             int64
#  8   add_to_cart_order      int64
#  9   reordered              int64
#  10  _merge                 category
#  11  Unnamed: 0             int64
#  12  product_name           object
#  13  aisle_id               int64
#  14  department_id          int64
#  15  prices                 float64
#  16  merge_flag             category
#  17  price_range_loc        object
#  18  busiest_day            object
#  19  busiest_days           object
#  20  busiest_period_of_day  object
# ...

# %%
ords_prods_merge.shape
# Out:
# (32404859, 21)

# %%
# dropping unnecessary columns
ords_prods_merge.drop(columns = {'_merge', 'Unnamed: 0', 'merge_flag'}, inplace = True)

# %%
ords_prods_merge.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2398795        1             2                   3                  7
# 2    473747        1             3                   3                 12
# 3   2254736        1             4                   4                  7
# 4    431534        1             5                   4                 15
#
#    days_since_last-order  new_customer  product_id  add_to_cart_order  \
# 0                    NaN          True         196                  1
# 1                   15.0         False         196                  1
# 2                   21.0         False         196                  1
# 3                   29.0         False         196                  1
# 4                   28.0         False         196                  1
#
#    reordered product_name  aisle_id  department_id  prices    price_range_loc  \
# ...

# %%
ords_prods_merge.shape
# Out:
# (32404859, 18)

# %%
ords_prods_merge.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 32404859 entries, 0 to 32404858
# Data columns (total 18 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   order_id               int64
#  1   user_id                int64
#  2   order_number           int64
#  3   orders_day_of_week     int64
#  4   order_hour_of_day      int64
#  5   days_since_last-order  float64
#  6   new_customer           bool
#  7   product_id             int64
#  8   add_to_cart_order      int64
#  9   reordered              int64
#  10  product_name           object
#  11  aisle_id               int64
#  12  department_id          int64
#  13  prices                 float64
#  14  price_range_loc        object
#  15  busiest_day            object
#  16  busiest_days           object
#  17  busiest_period_of_day  object
# dtypes: bool(1), float64(2), int64(10), object(5)
# memory usage: 4.4+ GB

# %%
ords_prods_merge.columns
# Out:
# Index(['order_id', 'user_id', 'order_number', 'orders_day_of_week',
#        'order_hour_of_day', 'days_since_last-order', 'new_customer',
#        'product_id', 'add_to_cart_order', 'reordered', 'product_name',
#        'aisle_id', 'department_id', 'prices', 'price_range_loc', 'busiest_day',
#        'busiest_days', 'busiest_period_of_day'],
#       dtype='object')

# %%
# Change types for ords_prods_merge data set

ords_prods_merge['order_id']=ords_prods_merge['order_id'].astype('int32')
ords_prods_merge['user_id'] = ords_prods_merge['user_id'].astype('int32')
ords_prods_merge['order_number']=ords_prods_merge['order_number'].astype('int8')
ords_prods_merge['orders_day_of_week']=ords_prods_merge['orders_day_of_week'].astype('int8')
ords_prods_merge['order_hour_of_day']=ords_prods_merge['order_hour_of_day'].astype('int8')
ords_prods_merge['days_since_last-order']=ords_prods_merge['days_since_last-order'].astype('float16')
ords_prods_merge['product_id'] =ords_prods_merge['product_id'].astype('int32')
ords_prods_merge['reordered']=ords_prods_merge['reordered'].astype('int8')
ords_prods_merge['add_to_cart_order']=ords_prods_merge['add_to_cart_order'].astype('int32')
ords_prods_merge['aisle_id'] = ords_prods_merge['aisle_id'].astype('int8')
ords_prods_merge['department_id'] = ords_prods_merge['department_id'].astype('int8')
ords_prods_merge['prices'] = ords_prods_merge['prices'].astype('float16')

# %%
ords_prods_merge.shape
# Out:
# (32404859, 18)

# %%
ords_prods_merge.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 32404859 entries, 0 to 32404858
# Data columns (total 18 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   order_id               int32
#  1   user_id                int32
#  2   order_number           int8
#  3   orders_day_of_week     int8
#  4   order_hour_of_day      int8
#  5   days_since_last-order  float16
#  6   new_customer           bool
#  7   product_id             int32
#  8   add_to_cart_order      int32
#  9   reordered              int8
#  10  product_name           object
#  11  aisle_id               int8
#  12  department_id          int8
#  13  prices                 float16
#  14  price_range_loc        object
#  15  busiest_day            object
#  16  busiest_days           object
#  17  busiest_period_of_day  object
# dtypes: bool(1), float16(2), int32(4), int8(6), object(5)
# memory usage: 2.3+ GB

# %%
ords_prods_merge.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2398795        1             2                   3                  7
# 2    473747        1             3                   3                 12
# 3   2254736        1             4                   4                  7
# 4    431534        1             5                   4                 15
#
#    days_since_last-order  new_customer  product_id  add_to_cart_order  \
# 0                    NaN          True         196                  1
# 1                   15.0         False         196                  1
# 2                   21.0         False         196                  1
# 3                   29.0         False         196                  1
# 4                   28.0         False         196                  1
#
#    reordered product_name  aisle_id  department_id  prices    price_range_loc  \
# ...

# %%
ords_prods_merge.tail()
# Out:
#           order_id  user_id  order_number  orders_day_of_week  \
# 32404854   1320836   202557            17                   2
# 32404855     31526   202557            18                   5
# 32404856    758936   203436             1                   2
# 32404857   2745165   203436             2                   3
# 32404858   3093936   205420             1                   4
#
#           order_hour_of_day  days_since_last-order  new_customer  product_id  \
# 32404854                 15                    1.0         False       43553
# 32404855                 11                    3.0         False       43553
# 32404856                  7                    NaN          True       42338
# 32404857                  5                   15.0         False       42338
# 32404858                 14                    NaN          True       28818
#
#           add_to_cart_order  reordered                   product_name  \
# ...

# %% [markdown]
# # Questions

# %% [markdown]
# # 1. Create a new notebook for this task. Be sure to import the relevant libraries, along with your ords_prods_merge dataframe

# %%
# Done

# %% [markdown]
# # 2. Find the aggregated mean of the “order_number” column grouped by “department_id” column for the entire dataframe

# %%
ords_prods_merge.groupby('department_id')['order_number'].mean()
# Out:
# department_id
# 1     15.457838
# 2     17.277920
# 3     17.170395
# 4     17.811403
# 5     15.215751
# 6     16.439806
# 7     17.225802
# 8     15.340650
# 9     15.895474
# 10    20.197148
# 11    16.170638
# 12    15.887671
# 13    16.583536
# 14    16.773669
# 15    16.165037
# 16    17.665606
# 17    15.694469
# 18    19.310397
# 19    17.177343
# 20    16.473447
# 21    22.902379
# Name: order_number, dtype: float64

# %% [markdown]
# # 3. Analyze the result. How do the results for the entire dataframe differ from those of the subset?

# %%
# Within the subset we have results only for some of the departments,
# The values for the mean, for those departments in the subset that we have results, differs from those for the entire dataframe.
# the mean is higher in the subset, except for department 17

# %% [markdown]
# # 4. Follow the instructions in the Exercise for creating a loyalty flag for existing customers using the transform() and loc() functions.

# %%
# Aggregating Data with transform()
ords_prods_merge['max_order'] = ords_prods_merge.groupby(['user_id'])['order_number'].transform(np.max)

# %%
# checking the output
ords_prods_merge.head(20)
# Out:
#     order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0    2539329        1             1                   2                  8
# 1    2398795        1             2                   3                  7
# 2     473747        1             3                   3                 12
# 3    2254736        1             4                   4                  7
# 4     431534        1             5                   4                 15
# 5    3367565        1             6                   2                  7
# 6     550135        1             7                   1                  9
# 7    3108588        1             8                   1                 14
# 8    2295261        1             9                   1                 16
# 9    2550362        1            10                   4                  8
# 10   2968173       15            15                   1                  9
# ...

# %%
# To create a loyalty flag, we are using the following criteria:

# 1. If the maximum orders the user has made is over 40, then the customer will be labeled a “Loyal customer.”
# 2. If the maximum orders the user has made is over 10 but less than or equal to 40, then the customer will be labeled a “Regular customer.”
# 3. If the maximum orders the user has made is less than or equal to 10, then the customer will be labeled a “New customer.”

# %%
ords_prods_merge.loc[ords_prods_merge['max_order'] > 40, 'loyalty_flag'] = 'Loyal customer'

# %%
ords_prods_merge.loc[(ords_prods_merge['max_order'] <= 40) & (ords_prods_merge['max_order'] > 10), 'loyalty_flag'] = 'Regular customer'

# %%
ords_prods_merge.loc[ords_prods_merge['max_order'] <= 10, 'loyalty_flag'] = 'New customer'

# %%
ords_prods_merge['loyalty_flag'].value_counts(dropna = False)
# Out:
# Regular customer    15876776
# Loyal customer      10284093
# New customer         6243990
# Name: loyalty_flag, dtype: int64

# %%
# checking the columns 'user_id', 'loyalty_flag', 'order_number' and 'max_order' 
ords_prods_merge[['user_id', 'loyalty_flag', 'order_number', 'max_order' ]].head(20)
# Out:
#     user_id      loyalty_flag  order_number  max_order
# 0         1      New customer             1         10
# 1         1      New customer             2         10
# 2         1      New customer             3         10
# 3         1      New customer             4         10
# 4         1      New customer             5         10
# 5         1      New customer             6         10
# 6         1      New customer             7         10
# 7         1      New customer             8         10
# 8         1      New customer             9         10
# 9         1      New customer            10         10
# 10       15  Regular customer            15         22
# 11       15  Regular customer            17         22
# 12       15  Regular customer            18         22
# 13       15  Regular customer            21         22
# 14       15  Regular customer            22         22
# 15       19      New customer             2          9
# ...

# %% [markdown]
# # 5. Check the basic statistics of the product prices for each loyalty category (Loyal Customer, Regular Customer, and New Customer).¶

# %%
ords_prods_merge.groupby('loyalty_flag').agg({'prices': ['mean', 'std', 'min', 'max', 'median']})
# Out:
#                  prices
#                    mean std  min  max    median
# loyalty_flag
# Loyal customer      NaN NaN  1.0  inf  7.398438
# New customer        NaN NaN  1.0  inf  7.398438
# Regular customer    NaN NaN  1.0  inf  7.398438

# %%
# the max value seems off, will be further addressed

# %%
# assign NaN to outliers values
ords_prods_merge.loc[ords_prods_merge['prices'] > 100]
# Out:
#           order_id  user_id  order_number  orders_day_of_week  \
# 10030345    912404       17            12                   2
# 10030346    603376       17            22                   6
# 10030347   3264360      135             2                   2
# 10030348    892534      135             3                   0
# 10030349    229704      342             8                   1
# ...            ...      ...           ...                 ...
# 29166209   2249946   204099            29                   0
# 29166210   2363282   204099            31                   0
# 29166211   3181945   204395            13                   3
# 29166212   2486215   205227             7                   3
# 29166213   2232716   205227            10                   0
#
#           order_hour_of_day  days_since_last-order  new_customer  product_id  \
# 10030345                 14                    5.0         False       21553
# ...

# %%
ords_prods_merge.loc[ords_prods_merge['prices'] >100, 'prices'] = np.nan

# %%
ords_prods_merge['prices'].max()
# Out:
# 25.0

# %%
# checking again 
ords_prods_merge.groupby('loyalty_flag').agg({'prices': ['mean', 'std', 'min', 'max', 'median']})
# Out:
#                     prices
#                       mean       std  min   max    median
# loyalty_flag
# Loyal customer    7.773438  4.206003  1.0  25.0  7.398438
# New customer      7.800781  4.266704  1.0  25.0  7.398438
# Regular customer  7.796875  4.254747  1.0  25.0  7.398438

# %%
# similar values accross the different customer categories

# %% [markdown]
# # 6. Create a spending flag for each user based on the average price across all their orders

# %%
# Aggregating Data with transform() and create new column 'user_avg_price'
ords_prods_merge['user_avg_price'] = ords_prods_merge.groupby(['user_id'])['prices'].transform(np.mean)

# %%
# checking the output
ords_prods_merge.head(15)
# Out:
#     order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0    2539329        1             1                   2                  8
# 1    2398795        1             2                   3                  7
# 2     473747        1             3                   3                 12
# 3    2254736        1             4                   4                  7
# 4     431534        1             5                   4                 15
# 5    3367565        1             6                   2                  7
# 6     550135        1             7                   1                  9
# 7    3108588        1             8                   1                 14
# 8    2295261        1             9                   1                 16
# 9    2550362        1            10                   4                  8
# 10   2968173       15            15                   1                  9
# ...

# %%
# To create a spending  flag, we are using the following criteria:
# If the mean of the prices of products purchased by a user is lower than 10, then flag them as a “Low spender.”
# If the mean of the prices of products purchased by a user is higher than or equal to 10, then flag them as a “High spender.”

# %%
ords_prods_merge.loc[ords_prods_merge['user_avg_price'] < 10, 'spending_flag'] = 'Low spender'

# %%
ords_prods_merge.loc[ords_prods_merge['user_avg_price'] >= 10, 'spending_flag'] = 'High spender'

# %%
# check the frequency
ords_prods_merge['spending_flag'].value_counts(dropna = False)
# Out:
# Low spender     32284736
# High spender      120123
# Name: spending_flag, dtype: int64

# %%
# checking the columns 'user_id', 'spending_flag', 'user_avg_price'
ords_prods_merge[['user_id', 'spending_flag', 'user_avg_price']].head(50)
# Out:
#     user_id spending_flag  user_avg_price
# 0         1   Low spender        6.367188
# 1         1   Low spender        6.367188
# 2         1   Low spender        6.367188
# 3         1   Low spender        6.367188
# 4         1   Low spender        6.367188
# 5         1   Low spender        6.367188
# 6         1   Low spender        6.367188
# 7         1   Low spender        6.367188
# 8         1   Low spender        6.367188
# 9         1   Low spender        6.367188
# 10       15   Low spender        3.980469
# 11       15   Low spender        3.980469
# 12       15   Low spender        3.980469
# 13       15   Low spender        3.980469
# 14       15   Low spender        3.980469
# 15       19   Low spender        8.375000
# 16       19   Low spender        8.375000
# 17       19   Low spender        8.375000
# 18       21   Low spender        7.011719
# 19       31   Low spender        8.140625
# 20       31   Low spender        8.140625
# ...

# %% [markdown]
# # 7.Determine frequent versus non-frequent customers. Create an order frequency flag that marks the regularity of a user’s ordering behavior according to the median in the “days_since_prior_order” column¶

# %%
 # Aggregating Data with transform() and create new column 'median_prior_orders'
ords_prods_merge['median_prior_orders'] = ords_prods_merge.groupby(['user_id'])['days_since_last-order'].transform(np.median)

# %%
# checking the output
ords_prods_merge.head(15)
# Out:
#     order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0    2539329        1             1                   2                  8
# 1    2398795        1             2                   3                  7
# 2     473747        1             3                   3                 12
# 3    2254736        1             4                   4                  7
# 4     431534        1             5                   4                 15
# 5    3367565        1             6                   2                  7
# 6     550135        1             7                   1                  9
# 7    3108588        1             8                   1                 14
# 8    2295261        1             9                   1                 16
# 9    2550362        1            10                   4                  8
# 10   2968173       15            15                   1                  9
# ...

# %%
# To create an order frequency flag, we are using the following criteria:
# if the median of “days_since_last_order” is higher than 20, then the customer should be labeled a “Non-frequent customer.”
# If the median is higher than 10 and lower than or equal to 20, then the customer should be labeled a “Regular customer.”
# If the median is lower than or equal to 10, then the customer should be labeled a “Frequent customer.”

# %%
ords_prods_merge.loc[ords_prods_merge['median_prior_orders'] > 20, 'order_frequency_flag'] = 'Non-frequent customer'

# %%
ords_prods_merge.loc[ords_prods_merge['median_prior_orders'] <= 10, 'order_frequency_flag'] = 'Frequent customer'

# %%
ords_prods_merge.loc[(ords_prods_merge['median_prior_orders'] > 10) & (ords_prods_merge['median_prior_orders'] <= 20), 'order_frequency_flag'] = 'Regular customer'

# %%
# check the frequency
ords_prods_merge['order_frequency_flag'].value_counts(dropna = False)
# Out:
# Frequent customer        21559853
# Regular customer          7208564
# Non-frequent customer     3636437
# NaN                             5
# Name: order_frequency_flag, dtype: int64

# %%
# in order to count each user only once
ords_prods_merge.groupby(['order_frequency_flag']).user_id.nunique()
# Out:
# order_frequency_flag
# Frequent customer        86596
# Non-frequent customer    59619
# Regular customer         59993
# Name: user_id, dtype: int64

# %%
ords_prods_merge.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 32404859 entries, 0 to 32404858
# Data columns (total 24 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   order_id               int32
#  1   user_id                int32
#  2   order_number           int8
#  3   orders_day_of_week     int8
#  4   order_hour_of_day      int8
#  5   days_since_last-order  float16
#  6   new_customer           bool
#  7   product_id             int32
#  8   add_to_cart_order      int32
#  9   reordered              int8
#  10  product_name           object
#  11  aisle_id               int8
#  12  department_id          int8
#  13  prices                 float16
#  14  price_range_loc        object
#  15  busiest_day            object
#  16  busiest_days           object
#  17  busiest_period_of_day  object
#  18  max_order              int8
#  19  loyalty_flag           object
#  20  user_avg_price         float16
#  21  spending_flag          object
# ...

# %%
# Export data to pkl
ords_prods_merge.to_pickle(os.path.join(path, 'Data','Prepared Data', 'orders_products_aggregated_max.pkl'))
